# %%
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt
import os,sys
from scipy import ndimage, misc
from helpers import *
import skimage.transform as st
import cv2
import imageio

# %%
# Loaded a set of images
root_dir = "training/"
image_dir = root_dir + "images/"
files = os.listdir(image_dir)
n = 100 # 100 images
#n = 104 # 100 images

print("Loading " + str(n) + " images")
imgs = [load_image(image_dir + files[i]) for i in range(n)]
print(files[0])

gt_dir = root_dir + "groundtruth/"
print("Loading " + str(n) + " images")
gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]
# Out:
# Loading 100 images
# satImage_009.png
# Loading 100 images

# %%
plt.imshow(imgs[2])
"""
    """

# %%
"""zue=np.rot90(imgs[2], k =1, axes=(0,1))
zie=ndimage.rotate(gt_imgs[2], 30, reshape=True,mode='mirror')
zie = misc.imresize(zie,(400,400))
plt.imshow(zie)
liste = []
for i in range(20):
    zie=ndimage.rotate(gt_imgs[i], 30, reshape=True,mode='mirror')
    zie = misc.imresize(zie,(400,400))
    liste.append(zie)"""
# Out:
# "zue=np.rot90(imgs[2], k =1, axes=(0,1))\nzie=ndimage.rotate(gt_imgs[2], 30, reshape=True,mode='mirror')\nzie = misc.imresize(zie,(400,400))\nplt.imshow(zie)\nliste = []\nfor i in range(20):\n    zie=ndimage.rotate(gt_imgs[i], 30, reshape=True,mode='mirror')\n    zie = misc.imresize(zie,(400,400))\n    liste.append(zie)"

# %%
for i in range(101):
    print(gt_imgs[i].shape)
# Out:
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# ...

# %%
i_width = 400
i_height = 400

for i in range(100):
    for angle in (15,30,45,60,90,100,180,270):
        img = imgs[i]
        img_gt = gt_imgs[i]
        
        img_changed = ndimage.rotate(img, angle, reshape=True,mode='mirror') #rotate image
        img_final = misc.imresize(img_changed, (i_height, i_width)) #resize to 400x400
        gt_img_changed = ndimage.rotate(img_gt, angle, reshape=True,mode='mirror') #rotate groundtruth
        gt_img_final = misc.imresize(gt_img_changed, (i_height, i_width)) #resize
        #print("hallohallo", img_final.shape)
        #print("halloihalli", gt_img_final.shape)
        imageio.imwrite('training/images/rotatedImage_{}_{}.png'.format(i,angle),img_final)        
        imageio.imwrite('training/groundtruth/rotatedImage_{}_{}.png'.format(i,angle),gt_img_final)        
        
        #plt.imsave('training/images/satImage_{}'.format(101+i),img_final)
        #plt.imsave('training/groundtruth/satImage_{}'.format(101+i),gt_img_final, cmap='Greys_r')
# Out:
# /home/valentin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   # Remove the CWD from sys.path while we load stuff.
# /home/valentin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   if sys.path[0] == '':

# %%
"""i_width = 400
i_height = 400

for i in range(100):
    #for angle in (15,30,45,60,90,100,180,270):
        #for angle in (15,30):
        img = imgs[i]
        img_gt = gt_imgs[i]
        
        img_changed = ndimage.rotate(img, 15, reshape=True,mode='mirror') #rotate image
        img_final = misc.imresize(img_changed, (i_height, i_width)) #resize to 400x400
        gt_img_changed = ndimage.rotate(img_gt, 15, reshape=True,mode='mirror') #rotate groundtruth
        gt_img_final = misc.imresize(gt_img_changed, (i_height, i_width)) #resize
        plt.imsave('training/images/satImage_{}'.format(101+i),img_changed)
        plt.imsave('training/groundtruth/satImage_{}'.format(101+i),gt_img_changed, cmap='Greys_r')
"""
# Out:
# /home/valentin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:11: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   # This is added back by InteractiveShellApp.init_path()
# /home/valentin/.local/lib/python3.6/site-packages/ipykernel_launcher.py:13: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.3.0.
# Use Pillow instead: ``numpy.array(Image.fromarray(arr).resize())``.
#   del sys.path[0]

# %%
# Loaded a set of images
root_dir = "training/"
image_dir = root_dir + "images/"
files = os.listdir(image_dir)
#n = 100 # 100 images
n = 900 # 100 images

print("Loading " + str(n) + " images")
imgs = [load_image(image_dir + files[i]) for i in range(n)]

gt_dir = root_dir + "groundtruth/"
print("Loading " + str(n) + " images")
gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]



for i in range(900):
    print(gt_imgs[i].shape)
    print(imgs[i].shape)
# Out:
# Loading 200 images
# satImage_009.png
# Loading 200 images
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# (400, 400, 3)
# ...

# %%
plt.imshow(imgs[1])

img = imgs[1]
mean = 0.02   # some constant
std = 0.01    # some constant (standard deviation)
noisy_img = img + np.random.normal(mean, std, img.shape)
noisy_img_clipped = np.clip(noisy_img, 0, 255)

plt.imshow(noisy_img_clipped)
print(img.shape)
print(noisy_img_clipped.shape)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (400, 400, 4)
# (400, 400, 4)

# %%
# load new images including all rotations. 
root_dir = "training/"
image_dir = root_dir + "images/"
filesInclNoise = os.listdir(image_dir)
n = 900 # 100 images
print("Loading " + str(n) + " images")
imgs = [load_image(image_dir + filesInclNoise[i]) for i in range(n)]
# Out:
# Loading 900 images
# satImage_009.png

# %%
# add random noise to each file

mean = 0.02   # some constant
std = 0.01    # some constant (standard deviation)

for i in range(900):
img = imgs[1]
noisy_img = img + np.random.normal(mean, std, img.shape)
noisy_img_clipped = np.clip(noisy_img, 0, 255)
# Out:
# newImage_74_30.png
